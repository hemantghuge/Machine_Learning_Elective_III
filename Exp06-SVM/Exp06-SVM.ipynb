# %% [markdown]
# ## Experiment No. 6 - Implement SVM classifier for classification of data into two classes.

# %% [markdown]
# Source 1 - https://github.com/adityajn105/SVM-From-Scratch
#
# Source 2 - https://pythonprogramming.net/machine-learning-tutorial-python-introduction/#google_vignette
#
# Source 3 - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
#
# Source 4 - https://towardsdatascience.com/svm-implementation-from-scratch-python-2db2fc52e5c2
#
# Source 5 - https://medium.com/deep-math-machine-learning-ai/chapter-3-1-svm-from-scratch-in-python-86f93f853dc
#
# Support Vector Machine

# %% [markdown]
# - **Data** -
# - **Task** -
# - **Mathematical Model** -
# - **Loss Function** -
# - **Learning Algorithm** -
# - **Model Evaluation** -
