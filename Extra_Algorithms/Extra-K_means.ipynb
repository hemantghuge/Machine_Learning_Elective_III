# %% [markdown]
# ## Extra - K means clustering

# %% [markdown]
# Source 1 - https://pythonmachinelearning.pro/data-clustering-with-k-means/

# %% [markdown]
# - **Data** -
# - **Task** -
# - **Mathematical Model** -
# - **Loss Function** -
# - **Learning Algorithm** -
# - **Model Evaluation** -
